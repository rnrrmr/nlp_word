# %%
import web_scraper_news as news
print(news.get_news())
# Out:
# 1: Israel losing global support over Gaza bombing - Biden
#
# 2: BTS go into the army - what now for K-pop's kings?
#
# 3: Brooklyn Nine-Nine star Andre Braugher dies aged 61
#
# 4: MoD fined after email blunder risked Afghan lives
#
# 5: Cricket Australia warns Khawaja over Gaza message
#
# 6: The Netflix show users spent 812m hours watching
#
# 7: UN General Assembly overwhelmingly demands Gaza ceasefire
#
# 8: Argentina begins 'shock therapy' by devaluing peso
#
# 9: Twenty-three killed in attack on Pakistan army base
#
# 10: BBC announces restructure to India operations
#
# 11: Twenty-three killed in attack on Pakistan army base
#
# 12: BBC announces restructure to India operations
#
# 13: Russia's new Black Sea naval base alarms Georgia
#
# 14: Aid stalemate overshadows Zelensky’s Washington trip
#
# 15: One man dominates Serbia's election - and he's not even running
#
# 16: Twelve-year-old climate activist storms COP28 stage
#
# ...
